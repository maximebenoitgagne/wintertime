# %% [markdown]
# # $Plot\ initial\ conditions\ of\ NO_3,\ PO_4\ and\ SiO_2$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
delZ1016mm=[-000.502938,-001.529108,-002.589326,-003.694104,
    -004.856893,-006.094686,-007.428598,-008.884300,-010.492119,
    -012.286569,-014.305046,-016.585499,-019.163105,-022.066351,
    -025.313251,-028.908703,-032.843723,-037.096832,-041.637131,
    -046.428223,-051.432011,-056.611771,-061.934135,-067.370148,
    -072.895531,-078.490440,-084.139015,-089.828743,-095.549858,
    -101.294853,-107.057938,-112.834717,-118.621834,-124.416748,
    -130.217529,-136.022751,-141.831299,-147.642349,-153.455292,
    -159.269653,-165.085068,-170.901291,-176.718124,-182.535400,
    -188.353012,-194.170883,-199.988953,-205.807159,-211.625488,
    -217.443878,-223.262344,-229.080856,-234.899399,-240.717972,
    -246.536560,-252.355164,-258.173767,-263.992401,-269.811035,
    -275.629669,-281.448303,-287.266937,-293.085571,-298.904205,
    -304.722870,-310.541504,-316.360138,-322.178802,-327.997437,
    -333.816101,-339.634735,-345.453369,-351.272034,-357.090668,
    -362.909332];

# %%
# adapted from
# https://stackoverflow.com/questions/3899980/how-to-change-the-font-size-on-a-matplotlib-plot
# answer of Pedro M Duarte
SMALL_SIZE = 8
MEDIUM_SIZE = 12
BIGGER_SIZE = 14

# plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the x tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the y tick labels
# plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# ## $NO_3$

# %%
infileNO3='1D_BB_NO3_GE_spring.delZ1016mm.32bits.bin'
inNO3=np.fromfile(infileNO3, dtype='>f')

# %% [markdown]
# ## PO_4

# %%
infilePO4='1D_BB_PO4_GE_spring.delZ1016mm.32bits.bin'
inPO4=np.fromfile(infilePO4, dtype='>f')

# %% [markdown]
# ## SiO_2

# %%
infileSiO2='1D_BB_Si_GE_spring.delZ1016mm.32bits.bin'
inSiO2=np.fromfile(infileSiO2, dtype='>f')

# %% [markdown]
# ## plot

# %%
# adapted from
# https://stackoverflow.com/questions/3899980/how-to-change-the-font-size-on-a-matplotlib-plot
# answer of Pedro M Duarte
SMALL_SIZE = 8
MEDIUM_SIZE = 20
BIGGER_SIZE = 28

# plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the x tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the y tick labels
# plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
plt.figure(figsize=(12,7))

plt.subplot(1, 3, 1)
plt.plot(inNO3,delZ1016mm)
plt.title('$NO_3$')
plt.xlabel('$NO_3\ (mmol\ N\ m^{-3})$')
plt.ylabel('$Depth\ (m)$')
plt.xlim(0,22)
plt.ylim(-400,0)
plt.grid(True)

plt.subplot(1, 3, 2)
plt.plot(inPO4,delZ1016mm)
plt.title('$PO_4$')
plt.xlabel('$PO_4\ (mmol\ P\ m^{-3})$')
locs, labels=plt.yticks()
plt.yticks(locs, '')
plt.xlim(0,22)
plt.ylim(-400,0)
plt.grid(True)

plt.subplot(1, 3, 3)
plt.plot(inSiO2,delZ1016mm)
plt.title('$Si{(OH)}_4$')
plt.xlabel('   $Si{(OH)}_4\ (mmol\ Si\ m^{-3})$')
locs, labels=plt.yticks()
plt.yticks(locs, '')
plt.xlim(0,22)
plt.ylim(-400,0)
plt.grid(True)

plt.tight_layout()
plt.savefig('1D_BB_NO3_PO4_Si_GE_spring.delZ1016mm.32bits.bin.png')
